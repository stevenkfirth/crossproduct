# %%
import matplotlib.pyplot as plt
from crossproduct import Point, Vector, Segment

# %%
#2D
fig, ax = plt.subplots()
Segment(Point(0,0),Point(1,1)).plot(ax,marker='o')

# %%
#3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
Segment(Point(0,0,0),Point(1,1,1)).plot(ax,marker='o')
