# %%
import matplotlib.pyplot as plt
from crossproduct import Point, Vector, Halfline

# %%
#2D
fig, ax = plt.subplots()
Halfline(Point(0,0),Vector(1,1)).plot(ax)

# %%
#3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
Halfline(Point(0,0,0),Vector(1,1,1)).plot(ax)
