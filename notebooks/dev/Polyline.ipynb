# %% [markdown]
# # Polyline

# %% [markdown]
# ## reverse

# %%
from crossproduct import Point,Polyline
pl = Polyline(Point(0,0), Point(1,0), Point(1,1))
result = pl.reverse
print(result)
# Out:
# Polyline(Point(1.0,1.0),Point(1.0,0.0),Point(0.0,0.0))

# %%
#2D
import matplotlib.pyplot as plt
from crossproduct import Point, Vector, Segment, Segments, Polylinefig, ax = plt.subplots()
Polyline(Point(0,0),Point(1,1),Point(2,1)).plot(ax,color='b',marker='o')

# %%
#3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
Polyline(Point(0,0,0),Point(1,1,1),Point(2,1,1)).plot(ax,color='b',marker='o')
